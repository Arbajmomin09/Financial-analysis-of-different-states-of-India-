# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r"C:/Project_finacial_analysis_states/Data set/Social_Sector_Expenditure.csv",encoding='latin1')

# %%
df1.head()
# Out:
#                State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh      532     613     697    1073    1193    1470    1849
# 1  Arunachal Pradesh                                                78
# 2              Assam     171     176     215     339     382     467     597
# 3              Bihar     452     598     673     677     758    1231    1353
# 4       Chhattisgarh                                                 
#
#   1987-88 1988-89  ...  2006-07  2007-08  2008-09  2009-10  2010-11  2011-12  \
# 0    1884    2103  ...  18654.0  24471.0  31440.0  30280.0  39130.0  45400.0
# 1     102     113  ...    843.0    953.0   1280.0   1770.0   1570.0   2160.0
# 2     681     727  ...   5220.0   6056.0   6760.0   9160.0  10240.0  11190.0
# 3    1431    1849  ...  11127.0  13815.0  16340.0  17870.0  19370.0  24050.0
# 4                ...   5707.0   6947.0   8870.0  11680.0  11820.0  14810.0
#
#    2012-13 2013-14 2014-15 2015-16 (RE)
# ...

# %%
df1.columns
# Out:
# Index(['State', '1980-81', '1981-82', '1982-83', '1983-84', '1984-85',
#        '1985-86', '1986-87', '1987-88', '1988-89', '1989-90', '1990-91',
#        '1991-92', '1992-93', '1993-94', '1994-95', '1995-96', '1996-97',
#        '1997-98', '1998-99', '1999-00', '2000-01', '2001-02', '2002-03',
#        '2003-04', '2004-05', '2005-06', '2006-07', '2007-08', '2008-09',
#        '2009-10', '2010-11', '2011-12', '2012-13', '2013-14', '2014-15',
#        '2015-16 (RE)'],
#       dtype='object')

# %%
df1.head()
# Out:
#                State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh      532     613     697    1073    1193    1470    1849
# 1  Arunachal Pradesh                                                78
# 2              Assam     171     176     215     339     382     467     597
# 3              Bihar     452     598     673     677     758    1231    1353
# 4       Chhattisgarh                                                 
#
#   1987-88 1988-89  ...  2006-07  2007-08  2008-09  2009-10  2010-11  2011-12  \
# 0    1884    2103  ...  18654.0  24471.0  31440.0  30280.0  39130.0  45400.0
# 1     102     113  ...    843.0    953.0   1280.0   1770.0   1570.0   2160.0
# 2     681     727  ...   5220.0   6056.0   6760.0   9160.0  10240.0  11190.0
# 3    1431    1849  ...  11127.0  13815.0  16340.0  17870.0  19370.0  24050.0
# 4                ...   5707.0   6947.0   8870.0  11680.0  11820.0  14810.0
#
#    2012-13 2013-14 2014-15 2015-16 (RE)
# ...

# %%
df1.set_index('State', inplace=True)

# %%
#df1.set_index('Year', inplace=True)

# %%
df = df1.transpose()

# %%
df.head()
# Out:
# State   Andhra Pradesh  Arunachal Pradesh Assam Bihar Chhattisgarh Goa  \
# 1980-81             532                    171   452               
# 1981-82             613                    176   598               
# 1982-83             697                    215   673               
# 1983-84            1073                    339   677               
# 1984-85            1193                    382   758               
#
# State   Gujarat Haryana Himachal Pradesh Jammu & Kashmir  ... Rajasthan  \
# 1980-81     406     137              106             125  ...       323
# 1981-82     472     173              113             134  ...       425
# 1982-83     643     235              128             149  ...       498
# 1983-84     669     242              139             179  ...       544
# 1984-85     841     281              156             215  ...       625
#
# State   Sikkim Tamil Nadu Telangana Tripura Uttar Pradesh Uttarakhand  \
# ...

# %%
df = df.replace('',0)

# %%
df.columns
# Out:
# Index(['Andhra Pradesh ', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Delhi', 'Puducherry'],
#       dtype='object', name='State')

# %%
for i in df.columns:
    df[i] = pd.to_numeric(df[i], errors = 'ignore')

# %%
df.dtypes
# Out:
# State
# Andhra Pradesh       float64
# Arunachal Pradesh    float64
# Assam                float64
# Bihar                float64
# Chhattisgarh         float64
# Goa                  float64
# Gujarat              float64
# Haryana              float64
# Himachal Pradesh     float64
# Jammu & Kashmir      float64
# Jharkhand            float64
# Karnataka            float64
# Kerala               float64
# Madhya Pradesh       float64
# Maharashtra          float64
# Manipur              float64
# Meghalaya            float64
# Mizoram              float64
# Nagaland             float64
# Odisha               float64
# Punjab               float64
# Rajasthan            float64
# Sikkim               float64
# Tamil Nadu           float64
# Telangana            float64
# Tripura              float64
# Uttar Pradesh        float64
# Uttarakhand          float64
# West Bengal          float64
# Delhi                float64
# Puducherry           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# State
# Andhra Pradesh        0
# Arunachal Pradesh     0
# Assam                 0
# Bihar                 0
# Chhattisgarh          0
# Goa                   0
# Gujarat               0
# Haryana               0
# Himachal Pradesh      0
# Jammu & Kashmir       0
# Jharkhand             0
# Karnataka             0
# Kerala                0
# Madhya Pradesh        0
# Maharashtra           0
# Manipur               0
# Meghalaya             0
# Mizoram               0
# Nagaland              0
# Odisha                0
# Punjab                0
# Rajasthan             0
# Sikkim                0
# Tamil Nadu            0
# Telangana            33
# Tripura               0
# Uttar Pradesh         0
# Uttarakhand           0
# West Bengal           0
# Delhi                 0
# Puducherry            0
# dtype: int64

# %%
df.fillna(0, inplace= True)

# %%
df.isnull().sum()
# Out:
# State
# Andhra Pradesh       0
# Arunachal Pradesh    0
# Assam                0
# Bihar                0
# Chhattisgarh         0
# Goa                  0
# Gujarat              0
# Haryana              0
# Himachal Pradesh     0
# Jammu & Kashmir      0
# Jharkhand            0
# Karnataka            0
# Kerala               0
# Madhya Pradesh       0
# Maharashtra          0
# Manipur              0
# Meghalaya            0
# Mizoram              0
# Nagaland             0
# Odisha               0
# Punjab               0
# Rajasthan            0
# Sikkim               0
# Tamil Nadu           0
# Telangana            0
# Tripura              0
# Uttar Pradesh        0
# Uttarakhand          0
# West Bengal          0
# Delhi                0
# Puducherry           0
# dtype: int64

# %%
df.head(10)
# Out:
# State    Andhra Pradesh   Arunachal Pradesh  Assam   Bihar  Chhattisgarh  \
# 1980-81            532.0                0.0  171.0   452.0           0.0
# 1981-82            613.0                0.0  176.0   598.0           0.0
# 1982-83            697.0                0.0  215.0   673.0           0.0
# 1983-84           1073.0                0.0  339.0   677.0           0.0
# 1984-85           1193.0                0.0  382.0   758.0           0.0
# 1985-86           1470.0                0.0  467.0  1231.0           0.0
# 1986-87           1849.0               78.0  597.0  1353.0           0.0
# 1987-88           1884.0              102.0  681.0  1431.0           0.0
# 1988-89           2103.0              113.0  727.0  1849.0           0.0
# 1989-90           2387.0              126.0  769.0  2027.0           0.0
#
# State      Goa  Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  ...  \
# 1980-81    0.0    406.0    137.0             106.0            125.0  ...
# ...

# %%
df.isnull().sum()
# Out:
# State
# Andhra Pradesh       0
# Arunachal Pradesh    0
# Assam                0
# Bihar                0
# Chhattisgarh         0
# Goa                  0
# Gujarat              0
# Haryana              0
# Himachal Pradesh     0
# Jammu & Kashmir      0
# Jharkhand            0
# Karnataka            0
# Kerala               0
# Madhya Pradesh       0
# Maharashtra          0
# Manipur              0
# Meghalaya            0
# Mizoram              0
# Nagaland             0
# Odisha               0
# Punjab               0
# Rajasthan            0
# Sikkim               0
# Tamil Nadu           0
# Telangana            0
# Tripura              0
# Uttar Pradesh        0
# Uttarakhand          0
# West Bengal          0
# Delhi                0
# Puducherry           0
# dtype: int64

# %%
df.head()
# Out:
# State    Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  Goa  \
# 1980-81            532.0                0.0  171.0  452.0           0.0  0.0
# 1981-82            613.0                0.0  176.0  598.0           0.0  0.0
# 1982-83            697.0                0.0  215.0  673.0           0.0  0.0
# 1983-84           1073.0                0.0  339.0  677.0           0.0  0.0
# 1984-85           1193.0                0.0  382.0  758.0           0.0  0.0
#
# State    Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  ...  Rajasthan  \
# 1980-81    406.0    137.0             106.0            125.0  ...      323.0
# 1981-82    472.0    173.0             113.0            134.0  ...      425.0
# 1982-83    643.0    235.0             128.0            149.0  ...      498.0
# 1983-84    669.0    242.0             139.0            179.0  ...      544.0
# 1984-85    841.0    281.0             156.0            215.0  ...      625.0
#
# ...

# %%
df.index = df.index.str.replace(r'\s*\(.*\)', '', regex=True)

# %%
df.tail()
# Out:
# State    Andhra Pradesh   Arunachal Pradesh    Assam    Bihar  Chhattisgarh  \
# 2011-12          45400.0             2160.0  11190.0  24050.0       14810.0
# 2012-13          49440.0             1940.0  12300.0  30740.0       16970.0
# 2013-14          53740.0             2550.0  14510.0  34920.0       21050.0
# 2014-15          46150.0             4150.0  28280.0  67080.0       30350.0
# 2015-16          52450.0             4060.0  27810.0  56140.0       37350.0
#
# State       Goa  Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  ...  \
# 2011-12  2300.0  30350.0  16270.0            6000.0           8740.0  ...
# 2012-13  2500.0  38060.0  18990.0            7100.0           9120.0  ...
# 2013-14  2920.0  41880.0  18100.0            7890.0           9810.0  ...
# 2014-15  3800.0  51980.0  26670.0            9560.0          13540.0  ...
# 2015-16  4680.0  57900.0  30790.0           11320.0          14200.0  ...
#
# ...

# %%
#df = df.drop(df.index[-1])

# %%
df['date'] = pd.to_datetime(df.index.str[:4], format='%Y', errors='coerce')

# %%
df.tail()
# Out:
# State    Andhra Pradesh   Arunachal Pradesh    Assam    Bihar  Chhattisgarh  \
# 2011-12          45400.0             2160.0  11190.0  24050.0       14810.0
# 2012-13          49440.0             1940.0  12300.0  30740.0       16970.0
# 2013-14          53740.0             2550.0  14510.0  34920.0       21050.0
# 2014-15          46150.0             4150.0  28280.0  67080.0       30350.0
# 2015-16          52450.0             4060.0  27810.0  56140.0       37350.0
#
# State       Goa  Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  ...  \
# 2011-12  2300.0  30350.0  16270.0            6000.0           8740.0  ...
# 2012-13  2500.0  38060.0  18990.0            7100.0           9120.0  ...
# 2013-14  2920.0  41880.0  18100.0            7890.0           9810.0  ...
# 2014-15  3800.0  51980.0  26670.0            9560.0          13540.0  ...
# 2015-16  4680.0  57900.0  30790.0           11320.0          14200.0  ...
#
# ...

# %%
df.head()
# Out:
# State    Andhra Pradesh   Arunachal Pradesh  Assam  Bihar  Chhattisgarh  Goa  \
# 1980-81            532.0                0.0  171.0  452.0           0.0  0.0
# 1981-82            613.0                0.0  176.0  598.0           0.0  0.0
# 1982-83            697.0                0.0  215.0  673.0           0.0  0.0
# 1983-84           1073.0                0.0  339.0  677.0           0.0  0.0
# 1984-85           1193.0                0.0  382.0  758.0           0.0  0.0
#
# State    Gujarat  Haryana  Himachal Pradesh  Jammu & Kashmir  ...  Sikkim  \
# 1980-81    406.0    137.0             106.0            125.0  ...     9.0
# 1981-82    472.0    173.0             113.0            134.0  ...    11.0
# 1982-83    643.0    235.0             128.0            149.0  ...    11.0
# 1983-84    669.0    242.0             139.0            179.0  ...    16.0
# 1984-85    841.0    281.0             156.0            215.0  ...    20.0
#
# ...

# %%
df.to_csv('Social_Sector_Expenditure2.csv', index=True)
